# %%
import numpy as np
import pandas as pd
import re

pd.options.display.max_rows = 50
pd.options.display.max_columns = 100

df = pd.read_csv('player_contracts.csv')

# %%
df
# Out:
#                            PLAYER POS             TEAM  AGE  YRS  \
# 0    Giancarlo Stanton(2015-2027)  RF              MIA   26   13
# 1       Alex Rodriguez(2008-2017)  DH              NYY   40   10
# 2       Miguel Cabrera(2016-2023)  1B              DET   33    8
# 3        Robinson Cano(2014-2023)  2B              SEA   33   10
# 4        Albert Pujols(2012-2021)  DH              LAA   36   10
# 5           Joey Votto(2014-2023)  1B              CIN   32   10
# 6          David Price(2016-2022)  SP              BOS   30    7
# 7      Clayton Kershaw(2014-2020)  SP              LAD   28    7
# 8       Prince Fielder(2012-2020)  DH  TEXSigned w/DET   32    9
# 9         Max Scherzer(2015-2021)  SP              WSH   31    7
# 10        Zack Greinke(2016-2021)  SP              ARI   32    6
# 11       C.C. Sabathia(2009-2015)  SP              NYY   35    8
# 12       Jason Heyward(2016-2023)  RF              CHC   26    8
# ...

# %%
df.join(Player.apply(lambda x: Series(x.split('('))))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bfc8d0e887dc> in <module>()
# ----> 1 df.join(Player.apply(lambda x: Series(x.split('('))))
#       2 df
#
# NameError: name 'Player' is not defined
